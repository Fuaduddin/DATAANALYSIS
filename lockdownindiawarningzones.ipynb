# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %%
dt=pd.read_csv(r"E:\GOOGLE DIGITAL GARAGE\DATA ANALYSIS\DATASET\lockdownindiawarningzones.csv")

# %%
dt.head()
# Out:
#    S.no                  District                        State        Zone
# 0     1            South Andamans  Andaman And Nicobar Islands    Red Zone
# 1     2                  Nicobars  Andaman And Nicobar Islands  Green Zone
# 2     3  North And Middle Andaman  Andaman And Nicobar Islands  Green Zone
# 3     4                   Kurnool               Andhra Pradesh    Red Zone
# 4     5                    Guntur               Andhra Pradesh    Red Zone

# %%
dt.columns
# Out:
# Index(['S.no', 'District', 'State', 'Zone'], dtype='object')

# %%
dt.info
# Out:
# <bound method DataFrame.info of      S.no                  District                        State        Zone
# 0       1            South Andamans  Andaman And Nicobar Islands    Red Zone
# 1       2                  Nicobars  Andaman And Nicobar Islands  Green Zone
# 2       3  North And Middle Andaman  Andaman And Nicobar Islands  Green Zone
# 3       4                   Kurnool               Andhra Pradesh    Red Zone
# 4       5                    Guntur               Andhra Pradesh    Red Zone
# ..    ...                       ...                          ...         ...
# 728   729                Coochbehar                  West Bengal  Green Zone
# 729   730          Dinajpur Dakshin                  West Bengal  Green Zone
# 730   731                   Purulia                  West Bengal  Green Zone
# 731   732                Alipurduar                  West Bengal  Green Zone
# 732   733                  Jhargram                  West Bengal  Green Zone
#
# ...

# %%
sns.countplot('District',data=dt)

# %%
sns.countplot('Zone',data=dt)

# %%
sns.countplot('Zone',data=dt,hue='State')
plt.legend(title = "State:",loc='center left',bbox_to_anchor=(1, 0, 0.5, 1),shadow=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ...
